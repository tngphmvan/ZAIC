# %%
from diffusers.pipelines.ddim import pipeline_ddim
from diffusers.models.unets.unet_2d import UNet2DModel
from diffusers.schedulers.scheduling_ddim import DDIMScheduler
unet = UNet2DModel()
scheduler = DDIMScheduler()
model = pipeline_ddim.DDIMPipeline(unet=unet, scheduler=scheduler)

# %%
print(model.
# Out:
# DDIMPipeline {
#   "_class_name": "DDIMPipeline",
#   "_diffusers_version": "0.35.2",
#   "scheduler": [
#     "diffusers",
#     "DDIMScheduler"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DModel"
#   ]
# }
